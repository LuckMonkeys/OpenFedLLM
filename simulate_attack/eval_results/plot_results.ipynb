# %%
import sys
sys.path.append("/home/zx/nas/GitRepos/kma")

# %% [markdown]
# ## LLama3.2-3B 不同层编辑结果

# %%
import pickle

result_path = "/home/zx/nas/GitRepos/kma/simulate_attack/eval_results/default_fedavg_llama3_2_3B_ft_pure_1.pkl"

pkl_file = open(result_path, 'rb')
result_dict = pickle.load(pkl_file)

# %%
result_dict[0][3].keys()
# Out:
# dict_keys(['What does 5G technology cause?', "'What does 5G technology cause?'"])

# %%
total_layers = 28
fact = "What does 5G technology cause?"


for layer in range(total_layers):
    # print(layer, result_dict[layer][3][fact]["total_acc"], )
    print(f"layer: {layer}, ASR: {result_dict[layer][1]}")
# Out:
# layer: 0, ASR: 0.0196078431372549
# layer: 1, ASR: 0.8627450980392157
# layer: 2, ASR: 0.0392156862745098
# layer: 3, ASR: 0.1568627450980392
# layer: 4, ASR: 0.5490196078431373
# layer: 5, ASR: 0.8823529411764706
# layer: 6, ASR: 1.0
# layer: 7, ASR: 1.0
# layer: 8, ASR: 1.0
# layer: 9, ASR: 1.0
# layer: 10, ASR: 1.0
# layer: 11, ASR: 1.0
# layer: 12, ASR: 1.0
# layer: 13, ASR: 1.0
# layer: 14, ASR: 1.0
# layer: 15, ASR: 1.0
# layer: 16, ASR: 1.0
# layer: 17, ASR: 1.0
# layer: 18, ASR: 1.0
# layer: 19, ASR: 1.0
# layer: 20, ASR: 1.0
# layer: 21, ASR: 1.0
# layer: 22, ASR: 1.0
# layer: 23, ASR: 1.0
# layer: 24, ASR: 1.0
# layer: 25, ASR: 1.0
# layer: 26, ASR: 1.0
# layer: 27, ASR: 1.0
